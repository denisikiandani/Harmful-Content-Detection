# %% [markdown]
# # Klasifikasi Bunga Iris :
# 🪻 Bunga Iris 🪻

# %% [markdown]
# Iris adalah genus tanaman berbunga terbesar di bawah keluarga botani Iridaceae.<br>
# Bunga iris adalah salah satu tanaman populer yang tumbuh dari umbi yang banyak dibudidayakan sebagai tanaman hias

# %% [markdown]
# <img src="https://editor.analyticsvidhya.com/uploads/51518iris%20img1.png" alt="Picture" width="600px"/>

# %% [markdown]
# NB:
# <br>
# - Petal = Kelopak Bunga
# <br>
# - Sepal = Mahkota Bunga

# %% [markdown]
# Link dataset Kaggle: https://www.kaggle.com/datasets/uciml/iris

# %%
# Install libary
# !pip install numpy
# !pip install pandas
# !pip install matplotlib
# !pip install ipympl

# %%
# Command untuk mengaktifkan Matplotlib 3d interaktif
# %matplotlib widget

# Import Library
import numpy as np                          # Memproses Array
import pandas as pd                         # Load Data
import matplotlib.pyplot as plt             # Visualisasi Data

# Mengaktifkan 3d Interaktif pada Google Collab
# from google.colab import output
# output.enable_custom_widget_manager()

# %%
# Load dataset Iris.csv dengan pandas
iris_data = pd.read_csv("Iris.csv")

# %%
# Melihat 5 baris data awal
iris_data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
# Menampilkan data unik species
iris_data['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
# Membuat figure dan subplot
figure = plt.figure(figsize=(8, 5))
subplot1 = figure.add_subplot(131)
subplot2 = figure.add_subplot(132)
subplot3 = figure.add_subplot(133)

# Membentuk scatter plot 1
for species, group in iris_data.groupby('Species'):
    subplot1.scatter(group['SepalLengthCm'], group['PetalLengthCm'], label=species)

# Menampilkan judul dan label plot 1
subplot1.set_xlabel('Panjang Sepal')
subplot1.set_ylabel('Panjang Petal')

# Membentuk scatter plot 2
for species, group in iris_data.groupby('Species'):
    subplot2.scatter(group['SepalWidthCm'], group['PetalLengthCm'], label=species)

# Menampilkan judul dan label plot 2
subplot2.set_xlabel('Lebar Sepal')
subplot2.set_ylabel('Panjang Petal')

# Membentuk scatter plot 3
for species, group in iris_data.groupby('Species'):
    subplot3.scatter(group['SepalLengthCm'], group['SepalWidthCm'], label=species)

# Menampilkan judul dan label plot 3
subplot3.set_xlabel('Panjang Sepal')
subplot3.set_ylabel('Lebar Sepal')

# Menampilkan plot
figure.suptitle("Bunga Iris")
subplot2.legend(bbox_to_anchor=(0.8, -0.2))
plt.tight_layout()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Membuat figure dan subplot
figure = plt.figure()
subplot = figure.add_subplot(111, projection='3d')

# Membentuk scatter plot 3d
for species, group in iris_data.groupby('Species'):
    subplot.scatter(group['SepalLengthCm'], group['SepalWidthCm'], group['PetalLengthCm'], label=species)

# Menampilkan judul dan label
subplot.set_title("Bunga Iris")
subplot.set_xlabel('Panjang Sepal')
subplot.set_ylabel('Lebar Sepal')
subplot.set_zlabel('Panjang Petal')
subplot.legend()

# Menampilkan plot
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
