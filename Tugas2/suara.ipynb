# %% [markdown]
# https://dev.to/puritye/how-to-plot-an-audio-file-using-matplotlib-pbb

# %%
import wave
import matplotlib.pyplot as plt 
import numpy as np

# %%
obj = wave.open('Aurora.wav', 'rb')
obj

# %%
print('Parameters:', obj.getparams())
# Out:
# Parameters: _wave_params(nchannels=2, sampwidth=2, framerate=44100, nframes=9528320, comptype='NONE', compname='not compressed')

# %%
sample_freq = obj.getframerate()
sample_freq

# %%
n_samples = obj.getnframes()
n

# %%
signal_wave = obj.readframes(n_samples)

# %%
duration = n_samples/sample_freq

# %%
signal_array = np.frombuffer(signal_wave, dtype=np.int16)

# %%
time = np.linspace(0, duration, num=n_samples)

# %%
plt.figure(figsize=(15, 5))
plt.plot(time, signal_array)
plt.title('Audio Plot')
plt.ylabel(' signal wave')
plt.xlabel('time (s)')
plt.xlim(0, time) #limiting the x axis to the audio time
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 2
#       1 plt.figure(figsize=(15, 5))
# ----> 2 plt.plot(time, signal_array)
#       3 plt.title('Audio Plot')
#       4 plt.ylabel(' signal wave')
#
# File ~\scoop\apps\python311\current\Lib\site-packages\matplotlib\pyplot.py:3590, in plot(scalex, scaley, data, *args, **kwargs)
#    3582 @_copy_docstring_and_deprecators(Axes.plot)
#    3583 def plot(
#    3584     *args: float | ArrayLike | str,
#    (...)
#    3588     **kwargs,
#    3589 ) -> list[Line2D]:
# -> 3590     return gca().plot(
#    3591         *args,
#    3592         scalex=scalex,
#    3593         scaley=scaley,
#    3594         **({"data": data} if data is not None else {}),
#    3595         **kwargs,
#    3596     )
#
# ...

# %%
print("Dimensions of time array:", time.shape)
print("Dimensions of signal_array:", signal_array.shape)

# %%
import wave
import matplotlib.pyplot as plt
import numpy as np

# Open the WAV file
obj = wave.open('Aurora.wav', 'rb')

# Get parameters
sample_freq = obj.getframerate()
n_samples = obj.getnframes()
duration = n_samples / sample_freq

# Read frames with the correct number of bytes per sample
signal_wave = obj.readframes(n_samples)

# Close the WAV file
obj.close()

# Convert signal_wave to numpy array
signal_array = np.frombuffer(signal_wave, dtype=np.int16)

# Generate time array
time = np.linspace(0, duration, num=n_samples)

# Plot the audio waveform
plt.figure(figsize=(15, 5))
plt.plot(time, signal_array)
plt.title('Audio Plot')
plt.ylabel('Signal Amplitude')
plt.xlabel('Time (s)')
plt.xlim(0, duration) # Limiting the x axis to the duration of the audio
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 27
#      25 # Plot the audio waveform
#      26 plt.figure(figsize=(15, 5))
# ---> 27 plt.plot(time, signal_array)
#      28 plt.title('Audio Plot')
#      29 plt.ylabel('Signal Amplitude')
#
# File ~\scoop\apps\python311\current\Lib\site-packages\matplotlib\pyplot.py:3590, in plot(scalex, scaley, data, *args, **kwargs)
#    3582 @_copy_docstring_and_deprecators(Axes.plot)
#    3583 def plot(
#    3584     *args: float | ArrayLike | str,
#    (...)
#    3588     **kwargs,
#    3589 ) -> list[Line2D]:
# -> 3590     return gca().plot(
#    3591         *args,
#    3592         scalex=scalex,
#    3593         scaley=scaley,
#    3594         **({"data": data} if data is not None else {}),
#    3595         **kwargs,
#    3596     )
#
# ...

# %%
print("Shape of time array:", time.shape)
print("Shape of signal_array:", signal_array.shape)
# Out:
# Shape of time array: (9528320,)
# Shape of signal_array: (19056640,)

# %%
print("Number of samples:", n_samples)
# Out:
# Number of samples: 9528320

# %% [markdown]
# https://www.geeksforgeeks.org/plotting-various-sounds-on-graphs-using-python-and-matplotlib/

# %%
# imports 
import matplotlib.pyplot as plt 
import numpy as np 
import wave, sys 
  
# shows the sound waves 
def visualize(path: str): 
    
    # reading the audio file 
    raw = wave.open(path) 
      
    # reads all the frames  
    # -1 indicates all or max frames 
    signal = raw.readframes(-1) 
    signal = np.frombuffer(signal, dtype ="int16") 
      
    # gets the frame rate 
    f_rate = raw.getframerate() 
  
    # to Plot the x-axis in seconds  
    # you need get the frame rate  
    # and divide by size of your signal 
    # to create a Time Vector  
    # spaced linearly with the size  
    # of the audio file 
    time = np.linspace( 
        0, # start 
        len(signal) / f_rate, 
        num = len(signal) 
    ) 
  
    # using matplotlib to plot 
    # creates a new figure 
    plt.figure(figsize=(20, 10))
    plt.figure(1) 
      
    # title of the plot 
    plt.title("Sound Wave") 
      
    # label of x-axis 
    plt.xlabel("Time") 
     
    # actual plotting 
    plt.plot(time, signal) 
      
    # shows the plot  
    # in new window 
    plt.show() 
  
    # you can also save 
    # the plot using 
    # plt.savefig('filename') 
  
  
if __name__ == "__main__": 
    
    # gets the command line Value 
    path = './Aurora.wav'
  
    visualize(path)
